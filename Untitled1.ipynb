# %%
import metabolyze as met

# %%
result = met.Analysis('skeleton_output.tsv','Groups.csv')

# %%
for comparison in result.dme_comparisons():
    print (comparison)
# Out:
# ('OLFR2', 'GPI1')
# ('GPI1', 'OLFR2')

# %%
dropdown_comparison = [' vs. '.join(list(x)) for x in result.dme_comparisons()]

# %%
test = zip((dropdown_comparison,result.dme_comparisons()))

# %%
(result.dme_comparisons()[0])
# Out:
# ('OLFR2', 'GPI1')

# %%
"'OLFR2', 'GPI1'"
# Out:
# "'OLFR2', 'GPI1'"

# %%
print(dropdown_list)
# Out:
# [{'Label': 'OLFR2 vs. GPI1', 'value': ('OLFR2', 'GPI1')}, {'Label': 'GPI1 vs. OLFR2', 'value': ('GPI1', 'OLFR2')}]

# %%
test = ["'OLFR2'", " 'GPI1'"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-4b46550418c5> in <module>
#       1 test = ["'OLFR2'", " 'GPI1'"]
# ----> 2 test.replace(" ", "")
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
[x[1:-1] for x in test]
# Out:
# ['OLFR2', "'GPI1"]

# %%
for value in ["'OLFR2'", "'GPI1'"]:
    print(value[1:-1])
    #print(value[1:-1])
# Out:
# OLFR2
# GPI1

# %%
[value[1:-1] for value in ["'OLFR2'", "'GPI1'"]]
# Out:
# ['OLFR2', 'GPI1']

# %%
import pandas as pd
x = pd.read_csv('Intensity.values.csv')

# %%
y = []
y.append(x.shape[1])

# %%
y
# Out:
# [8]
